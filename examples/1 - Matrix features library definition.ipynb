# %% [markdown]
# # Matrix features library definition
# In this notebook, we explore how a library of matrix features can be created.

# %%
import numpy as np
from matsindy.feature_library import FeatureLibrary

# %% [markdown]
# Matrix libraries will take data in the form of a dictionary and access the variables using their name. Therefore we need to specify which names we want to involve in the library by defining `variable_names`. Another useful parameter is the `transpose_map` dictionary where we write information about the transpose of the variables. In this dictionary, a key is a variable name of the dataset, and the value is:
# - Same name if the variable is symmetric;
# - Same name with a leading `-` if the variable is skew;
# - The name of the transpose if it is present in the dataset;
# - `None` otherwise.
#
# Here we will be using the stress `'S'` which is symmetric, and both the velocity gradient `'∇U'` and its transposed `'∇Uᵀ'`.

# %%
variable_names = {'S', '∇U', '∇Uᵀ'}
transpose_map = {'S':'S', '∇U':'∇Uᵀ', '∇Uᵀ':'∇U'}

# %% [markdown]
# Now we can create a new library containing polynomial terms by calling `from_polynomial_matrices`. We need to provide:
# 1. `n_terms`: number of mutliplication terms.
# 2. `intercept`: include the identity matrix as a feature.
# 3. `symmetry`: symmetry property of the feature. Here we want only symmetric features.

# %%
library = FeatureLibrary.from_polynomial_matrices(variable_names=variable_names, 
                                                  transpose_map=transpose_map, 
                                                  n_terms=4, intercept=True, symmetry='symmetric')
library
# Out:
# Type of feature output: matrix
# Symmetry of features: symmetric
# Variables names: {'S', '∇U', '∇Uᵀ'}
# Variables transpose map: {'S': 'S', '∇U': '∇Uᵀ', '∇Uᵀ': '∇U'}
# Number of feature_functions: 69
# (0)	I
# (1)	S
# (2)	∇U + (∇U)ᵀ
# (3)	S∘S
# (4)	S∘∇U + (S∘∇U)ᵀ
# (5)	S∘∇Uᵀ + (S∘∇Uᵀ)ᵀ
# (6)	∇U∘∇U + (∇U∘∇U)ᵀ
# (7)	∇U∘∇Uᵀ
# (8)	∇Uᵀ∘∇U
# (9)	S∘S∘S
# (10)	S∘S∘∇U + (S∘S∘∇U)ᵀ
# (11)	S∘S∘∇Uᵀ + (S∘S∘∇Uᵀ)ᵀ
# (12)	S∘∇U∘S + (S∘∇U∘S)ᵀ
# (13)	S∘∇U∘∇U + (S∘∇U∘∇U)ᵀ
# (14)	S∘∇U∘∇Uᵀ + (S∘∇U∘∇Uᵀ)ᵀ
# (15)	S∘∇Uᵀ∘∇U + (S∘∇Uᵀ∘∇U)ᵀ
# (16)	S∘∇Uᵀ∘∇Uᵀ + (S∘∇Uᵀ∘∇Uᵀ)ᵀ
# (17)	∇U∘S∘∇U + (∇U∘S∘∇U)ᵀ
# (18)	∇U∘S∘∇Uᵀ
# (19)	∇U∘∇U∘∇U + (∇U∘∇U∘∇U)ᵀ
# (20)	∇U∘∇U∘∇Uᵀ + (∇U∘∇U∘∇Uᵀ)ᵀ
# (21)	∇U∘∇Uᵀ∘∇U + (∇U∘∇Uᵀ∘∇U)ᵀ
# (22)	∇Uᵀ∘S∘∇U
# (23)	∇Uᵀ∘∇U∘∇U + (∇Uᵀ∘∇U∘∇U)ᵀ
# (24)	S∘S∘S∘S
# (25)	S∘S∘S∘∇U + (S∘S∘S∘∇U)ᵀ
# (26)	S∘S∘S∘∇Uᵀ + (S∘S∘S∘∇Uᵀ)ᵀ
# (27)	S∘S∘∇U∘S + (S∘S∘∇U∘S)ᵀ
# (28)	S∘S∘∇U∘∇U + (S∘S∘∇U∘∇U)ᵀ
# (29)	S∘S∘∇U∘∇Uᵀ + (S∘S∘∇U∘∇Uᵀ)ᵀ
# (30)	S∘S∘∇Uᵀ∘S + (S∘S∘∇Uᵀ∘S)ᵀ
# (31)	S∘S∘∇Uᵀ∘∇U + (S∘S∘∇Uᵀ∘∇U)ᵀ
# (32)	S∘S∘∇Uᵀ∘∇Uᵀ + (S∘S∘∇Uᵀ∘∇Uᵀ)ᵀ
# (33)	S∘∇U∘S∘∇U + (S∘∇U∘S∘∇U)ᵀ
# (34)	S∘∇U∘S∘∇Uᵀ + (S∘∇U∘S∘∇Uᵀ)ᵀ
# (35)	S∘∇U∘∇U∘S + (S∘∇U∘∇U∘S)ᵀ
# (36)	S∘∇U∘∇U∘∇U + (S∘∇U∘∇U∘∇U)ᵀ
# (37)	S∘∇U∘∇U∘∇Uᵀ + (S∘∇U∘∇U∘∇Uᵀ)ᵀ
# (38)	S∘∇U∘∇Uᵀ∘S
# (39)	S∘∇U∘∇Uᵀ∘∇U + (S∘∇U∘∇Uᵀ∘∇U)ᵀ
# (40)	S∘∇U∘∇Uᵀ∘∇Uᵀ + (S∘∇U∘∇Uᵀ∘∇Uᵀ)ᵀ
# (41)	S∘∇Uᵀ∘S∘∇U + (S∘∇Uᵀ∘S∘∇U)ᵀ
# (42)	S∘∇Uᵀ∘S∘∇Uᵀ + (S∘∇Uᵀ∘S∘∇Uᵀ)ᵀ
# (43)	S∘∇Uᵀ∘∇U∘S
# (44)	S∘∇Uᵀ∘∇U∘∇U + (S∘∇Uᵀ∘∇U∘∇U)ᵀ
# (45)	S∘∇Uᵀ∘∇U∘∇Uᵀ + (S∘∇Uᵀ∘∇U∘∇Uᵀ)ᵀ
# (46)	S∘∇Uᵀ∘∇Uᵀ∘∇U + (S∘∇Uᵀ∘∇Uᵀ∘∇U)ᵀ
# (47)	S∘∇Uᵀ∘∇Uᵀ∘∇Uᵀ + (S∘∇Uᵀ∘∇Uᵀ∘∇Uᵀ)ᵀ
# (48)	∇U∘S∘S∘∇U + (∇U∘S∘S∘∇U)ᵀ
# (49)	∇U∘S∘S∘∇Uᵀ
# (50)	∇U∘S∘∇U∘∇U + (∇U∘S∘∇U∘∇U)ᵀ
# (51)	∇U∘S∘∇U∘∇Uᵀ + (∇U∘S∘∇U∘∇Uᵀ)ᵀ
# (52)	∇U∘S∘∇Uᵀ∘∇U + (∇U∘S∘∇Uᵀ∘∇U)ᵀ
# (53)	∇U∘S∘∇Uᵀ∘∇Uᵀ + (∇U∘S∘∇Uᵀ∘∇Uᵀ)ᵀ
# (54)	∇U∘∇U∘S∘∇U + (∇U∘∇U∘S∘∇U)ᵀ
# (55)	∇U∘∇U∘∇U∘∇U + (∇U∘∇U∘∇U∘∇U)ᵀ
# (56)	∇U∘∇U∘∇U∘∇Uᵀ + (∇U∘∇U∘∇U∘∇Uᵀ)ᵀ
# (57)	∇U∘∇U∘∇Uᵀ∘∇U + (∇U∘∇U∘∇Uᵀ∘∇U)ᵀ
# (58)	∇U∘∇U∘∇Uᵀ∘∇Uᵀ
# (59)	∇U∘∇Uᵀ∘S∘∇U + (∇U∘∇Uᵀ∘S∘∇U)ᵀ
# (60)	∇U∘∇Uᵀ∘∇U∘∇U + (∇U∘∇Uᵀ∘∇U∘∇U)ᵀ
# (61)	∇U∘∇Uᵀ∘∇U∘∇Uᵀ
# (62)	∇U∘∇Uᵀ∘∇Uᵀ∘∇U + (∇U∘∇Uᵀ∘∇Uᵀ∘∇U)ᵀ
# (63)	∇Uᵀ∘S∘S∘∇U
# (64)	∇Uᵀ∘S∘∇U∘∇U + (∇Uᵀ∘S∘∇U∘∇U)ᵀ
# (65)	∇Uᵀ∘S∘∇Uᵀ∘∇U + (∇Uᵀ∘S∘∇Uᵀ∘∇U)ᵀ
# (66)	∇Uᵀ∘∇U∘∇U∘∇U + (∇Uᵀ∘∇U∘∇U∘∇U)ᵀ
# (67)	∇Uᵀ∘∇U∘∇Uᵀ∘∇U
# (68)	∇Uᵀ∘∇Uᵀ∘∇U∘∇U

# %% [markdown]
# We will also make a scalar library which returns the trace of these polynomial terms. Note that trivially equal features have been removed.

# %%
library_trace = FeatureLibrary.from_polynomial_traces(variable_names, transpose_map, n_terms=4, intercept=False)
library_trace
# Out:
# Type of feature output: scalar
# Variables names: {'S', '∇U', '∇Uᵀ'}
# Variables transpose map: {'S': 'S', '∇U': '∇Uᵀ', '∇Uᵀ': '∇U'}
# Number of feature_functions: 28
# (0)	tr(S)
# (1)	tr(∇U)
# (2)	tr(S∘S)
# (3)	tr(S∘∇U)
# (4)	tr(∇U∘∇U)
# (5)	tr(∇U∘∇Uᵀ)
# (6)	tr(S∘S∘S)
# (7)	tr(S∘S∘∇U)
# (8)	tr(S∘∇U∘∇U)
# (9)	tr(S∘∇U∘∇Uᵀ)
# (10)	tr(S∘∇Uᵀ∘∇U)
# (11)	tr(∇U∘∇U∘∇U)
# (12)	tr(∇U∘∇U∘∇Uᵀ)
# (13)	tr(S∘S∘S∘S)
# (14)	tr(S∘S∘S∘∇U)
# (15)	tr(S∘S∘∇U∘∇U)
# (16)	tr(S∘S∘∇U∘∇Uᵀ)
# (17)	tr(S∘S∘∇Uᵀ∘∇U)
# (18)	tr(S∘∇U∘S∘∇U)
# (19)	tr(S∘∇U∘S∘∇Uᵀ)
# (20)	tr(S∘∇U∘∇U∘∇U)
# (21)	tr(S∘∇U∘∇U∘∇Uᵀ)
# (22)	tr(S∘∇U∘∇Uᵀ∘∇U)
# (23)	tr(S∘∇Uᵀ∘∇U∘∇U)
# (24)	tr(∇U∘∇U∘∇U∘∇U)
# (25)	tr(∇U∘∇U∘∇U∘∇Uᵀ)
# (26)	tr(∇U∘∇U∘∇Uᵀ∘∇Uᵀ)
# (27)	tr(∇U∘∇Uᵀ∘∇U∘∇Uᵀ)

# %% [markdown]
# Before we go on, we will remove `tr(∇U)` from the library as we expect this should be null from imcompressibility assumption.

# %%
library_trace.remove_by_name('tr(∇U)')
# Out:
# Type of feature output: scalar
# Variables names: {'S', '∇U', '∇Uᵀ'}
# Variables transpose map: {'S': 'S', '∇U': '∇Uᵀ', '∇Uᵀ': '∇U'}
# Number of feature_functions: 27
# (0)	tr(S)
# (1)	tr(S∘S)
# (2)	tr(S∘∇U)
# (3)	tr(∇U∘∇U)
# (4)	tr(∇U∘∇Uᵀ)
# (5)	tr(S∘S∘S)
# (6)	tr(S∘S∘∇U)
# (7)	tr(S∘∇U∘∇U)
# (8)	tr(S∘∇U∘∇Uᵀ)
# (9)	tr(S∘∇Uᵀ∘∇U)
# (10)	tr(∇U∘∇U∘∇U)
# (11)	tr(∇U∘∇U∘∇Uᵀ)
# (12)	tr(S∘S∘S∘S)
# (13)	tr(S∘S∘S∘∇U)
# (14)	tr(S∘S∘∇U∘∇U)
# (15)	tr(S∘S∘∇U∘∇Uᵀ)
# (16)	tr(S∘S∘∇Uᵀ∘∇U)
# (17)	tr(S∘∇U∘S∘∇U)
# (18)	tr(S∘∇U∘S∘∇Uᵀ)
# (19)	tr(S∘∇U∘∇U∘∇U)
# (20)	tr(S∘∇U∘∇U∘∇Uᵀ)
# (21)	tr(S∘∇U∘∇Uᵀ∘∇U)
# (22)	tr(S∘∇Uᵀ∘∇U∘∇U)
# (23)	tr(∇U∘∇U∘∇U∘∇U)
# (24)	tr(∇U∘∇U∘∇U∘∇Uᵀ)
# (25)	tr(∇U∘∇U∘∇Uᵀ∘∇Uᵀ)
# (26)	tr(∇U∘∇Uᵀ∘∇U∘∇Uᵀ)

# %% [markdown]
# Next we will further increase the complexity by 'tensorifying' the library with itself.

# %%
library_trace = library_trace + library_trace*library_trace
library_trace
# Out:
# Type of feature output: scalar
# Variables names: {'S', '∇U', '∇Uᵀ'}
# Variables transpose map: {'S': 'S', '∇U': '∇Uᵀ', '∇Uᵀ': '∇U'}
# Number of feature_functions: 405
# (0)	tr(S)
# (1)	tr(S∘S)
# (2)	tr(S∘∇U)
# (3)	tr(∇U∘∇U)
# (4)	tr(∇U∘∇Uᵀ)
# (5)	tr(S∘S∘S)
# (6)	tr(S∘S∘∇U)
# (7)	tr(S∘∇U∘∇U)
# (8)	tr(S∘∇U∘∇Uᵀ)
# (9)	tr(S∘∇Uᵀ∘∇U)
# (10)	tr(∇U∘∇U∘∇U)
# (11)	tr(∇U∘∇U∘∇Uᵀ)
# (12)	tr(S∘S∘S∘S)
# (13)	tr(S∘S∘S∘∇U)
# (14)	tr(S∘S∘∇U∘∇U)
# (15)	tr(S∘S∘∇U∘∇Uᵀ)
# (16)	tr(S∘S∘∇Uᵀ∘∇U)
# (17)	tr(S∘∇U∘S∘∇U)
# (18)	tr(S∘∇U∘S∘∇Uᵀ)
# (19)	tr(S∘∇U∘∇U∘∇U)
# (20)	tr(S∘∇U∘∇U∘∇Uᵀ)
# (21)	tr(S∘∇U∘∇Uᵀ∘∇U)
# (22)	tr(S∘∇Uᵀ∘∇U∘∇U)
# (23)	tr(∇U∘∇U∘∇U∘∇U)
# (24)	tr(∇U∘∇U∘∇U∘∇Uᵀ)
# (25)	tr(∇U∘∇U∘∇Uᵀ∘∇Uᵀ)
# (26)	tr(∇U∘∇Uᵀ∘∇U∘∇Uᵀ)
# (27)	(tr(S))²
# (28)	tr(S)tr(S∘S)
# (29)	tr(S)tr(S∘∇U)
# (30)	tr(S)tr(∇U∘∇U)
# (31)	tr(S)tr(∇U∘∇Uᵀ)
# (32)	tr(S)tr(S∘S∘S)
# (33)	tr(S)tr(S∘S∘∇U)
# (34)	tr(S)tr(S∘∇U∘∇U)
# (35)	tr(S)tr(S∘∇U∘∇Uᵀ)
# (36)	tr(S)tr(S∘∇Uᵀ∘∇U)
# (37)	tr(S)tr(∇U∘∇U∘∇U)
# (38)	tr(S)tr(∇U∘∇U∘∇Uᵀ)
# (39)	tr(S)tr(S∘S∘S∘S)
# (40)	tr(S)tr(S∘S∘S∘∇U)
# (41)	tr(S)tr(S∘S∘∇U∘∇U)
# (42)	tr(S)tr(S∘S∘∇U∘∇Uᵀ)
# (43)	tr(S)tr(S∘S∘∇Uᵀ∘∇U)
# (44)	tr(S)tr(S∘∇U∘S∘∇U)
# (45)	tr(S)tr(S∘∇U∘S∘∇Uᵀ)
# (46)	tr(S)tr(S∘∇U∘∇U∘∇U)
# (47)	tr(S)tr(S∘∇U∘∇U∘∇Uᵀ)
# (48)	tr(S)tr(S∘∇U∘∇Uᵀ∘∇U)
# (49)	tr(S)tr(S∘∇Uᵀ∘∇U∘∇U)
# (50)	tr(S)tr(∇U∘∇U∘∇U∘∇U)
# (51)	tr(S)tr(∇U∘∇U∘∇U∘∇Uᵀ)
# (52)	tr(S)tr(∇U∘∇U∘∇Uᵀ∘∇Uᵀ)
# (53)	tr(S)tr(∇U∘∇Uᵀ∘∇U∘∇Uᵀ)
# (54)	(tr(S∘S))²
# (55)	tr(S∘S)tr(S∘∇U)
# (56)	tr(S∘S)tr(∇U∘∇U)
# (57)	tr(S∘S)tr(∇U∘∇Uᵀ)
# (58)	tr(S∘S)tr(S∘S∘S)
# (59)	tr(S∘S)tr(S∘S∘∇U)
# (60)	tr(S∘S)tr(S∘∇U∘∇U)
# (61)	tr(S∘S)tr(S∘∇U∘∇Uᵀ)
# (62)	tr(S∘S)tr(S∘∇Uᵀ∘∇U)
# (63)	tr(S∘S)tr(∇U∘∇U∘∇U)
# (64)	tr(S∘S)tr(∇U∘∇U∘∇Uᵀ)
# (65)	tr(S∘S)tr(S∘S∘S∘S)
# (66)	tr(S∘S)tr(S∘S∘S∘∇U)
# (67)	tr(S∘S)tr(S∘S∘∇U∘∇U)
# (68)	tr(S∘S)tr(S∘S∘∇U∘∇Uᵀ)
# (69)	tr(S∘S)tr(S∘S∘∇Uᵀ∘∇U)
# (70)	tr(S∘S)tr(S∘∇U∘S∘∇U)
# (71)	tr(S∘S)tr(S∘∇U∘S∘∇Uᵀ)
# (72)	tr(S∘S)tr(S∘∇U∘∇U∘∇U)
# (73)	tr(S∘S)tr(S∘∇U∘∇U∘∇Uᵀ)
# (74)	tr(S∘S)tr(S∘∇U∘∇Uᵀ∘∇U)
# (75)	tr(S∘S)tr(S∘∇Uᵀ∘∇U∘∇U)
# (76)	tr(S∘S)tr(∇U∘∇U∘∇U∘∇U)
# (77)	tr(S∘S)tr(∇U∘∇U∘∇U∘∇Uᵀ)
# (78)	tr(S∘S)tr(∇U∘∇U∘∇Uᵀ∘∇Uᵀ)
# (79)	tr(S∘S)tr(∇U∘∇Uᵀ∘∇U∘∇Uᵀ)
# (80)	(tr(S∘∇U))²
# (81)	tr(S∘∇U)tr(∇U∘∇U)
# (82)	tr(S∘∇U)tr(∇U∘∇Uᵀ)
# (83)	tr(S∘∇U)tr(S∘S∘S)
# (84)	tr(S∘∇U)tr(S∘S∘∇U)
# (85)	tr(S∘∇U)tr(S∘∇U∘∇U)
# (86)	tr(S∘∇U)tr(S∘∇U∘∇Uᵀ)
# (87)	tr(S∘∇U)tr(S∘∇Uᵀ∘∇U)
# (88)	tr(S∘∇U)tr(∇U∘∇U∘∇U)
# (89)	tr(S∘∇U)tr(∇U∘∇U∘∇Uᵀ)
# (90)	tr(S∘∇U)tr(S∘S∘S∘S)
# (91)	tr(S∘∇U)tr(S∘S∘S∘∇U)
# (92)	tr(S∘∇U)tr(S∘S∘∇U∘∇U)
# (93)	tr(S∘∇U)tr(S∘S∘∇U∘∇Uᵀ)
# (94)	tr(S∘∇U)tr(S∘S∘∇Uᵀ∘∇U)
# (95)	tr(S∘∇U)tr(S∘∇U∘S∘∇U)
# (96)	tr(S∘∇U)tr(S∘∇U∘S∘∇Uᵀ)
# (97)	tr(S∘∇U)tr(S∘∇U∘∇U∘∇U)
# (98)	tr(S∘∇U)tr(S∘∇U∘∇U∘∇Uᵀ)
# (99)	tr(S∘∇U)tr(S∘∇U∘∇Uᵀ∘∇U)
# (100)	tr(S∘∇U)tr(S∘∇Uᵀ∘∇U∘∇U)
# (101)	tr(S∘∇U)tr(∇U∘∇U∘∇U∘∇U)
# (102)	tr(S∘∇U)tr(∇U∘∇U∘∇U∘∇Uᵀ)
# (103)	tr(S∘∇U)tr(∇U∘∇U∘∇Uᵀ∘∇Uᵀ)
# (104)	tr(S∘∇U)tr(∇U∘∇Uᵀ∘∇U∘∇Uᵀ)
# (105)	(tr(∇U∘∇U))²
# (106)	tr(∇U∘∇U)tr(∇U∘∇Uᵀ)
# (107)	tr(∇U∘∇U)tr(S∘S∘S)
# (108)	tr(∇U∘∇U)tr(S∘S∘∇U)
# (109)	tr(∇U∘∇U)tr(S∘∇U∘∇U)
# (110)	tr(∇U∘∇U)tr(S∘∇U∘∇Uᵀ)
# (111)	tr(∇U∘∇U)tr(S∘∇Uᵀ∘∇U)
# (112)	tr(∇U∘∇U)tr(∇U∘∇U∘∇U)
# (113)	tr(∇U∘∇U)tr(∇U∘∇U∘∇Uᵀ)
# (114)	tr(∇U∘∇U)tr(S∘S∘S∘S)
# (115)	tr(∇U∘∇U)tr(S∘S∘S∘∇U)
# (116)	tr(∇U∘∇U)tr(S∘S∘∇U∘∇U)
# (117)	tr(∇U∘∇U)tr(S∘S∘∇U∘∇Uᵀ)
# (118)	tr(∇U∘∇U)tr(S∘S∘∇Uᵀ∘∇U)
# (119)	tr(∇U∘∇U)tr(S∘∇U∘S∘∇U)
# (120)	tr(∇U∘∇U)tr(S∘∇U∘S∘∇Uᵀ)
# (121)	tr(∇U∘∇U)tr(S∘∇U∘∇U∘∇U)
# (122)	tr(∇U∘∇U)tr(S∘∇U∘∇U∘∇Uᵀ)
# (123)	tr(∇U∘∇U)tr(S∘∇U∘∇Uᵀ∘∇U)
# (124)	tr(∇U∘∇U)tr(S∘∇Uᵀ∘∇U∘∇U)
# (125)	tr(∇U∘∇U)tr(∇U∘∇U∘∇U∘∇U)
# (126)	tr(∇U∘∇U)tr(∇U∘∇U∘∇U∘∇Uᵀ)
# (127)	tr(∇U∘∇U)tr(∇U∘∇U∘∇Uᵀ∘∇Uᵀ)
# (128)	tr(∇U∘∇U)tr(∇U∘∇Uᵀ∘∇U∘∇Uᵀ)
# (129)	(tr(∇U∘∇Uᵀ))²
# (130)	tr(∇U∘∇Uᵀ)tr(S∘S∘S)
# (131)	tr(∇U∘∇Uᵀ)tr(S∘S∘∇U)
# (132)	tr(∇U∘∇Uᵀ)tr(S∘∇U∘∇U)
# (133)	tr(∇U∘∇Uᵀ)tr(S∘∇U∘∇Uᵀ)
# (134)	tr(∇U∘∇Uᵀ)tr(S∘∇Uᵀ∘∇U)
# (135)	tr(∇U∘∇Uᵀ)tr(∇U∘∇U∘∇U)
# (136)	tr(∇U∘∇Uᵀ)tr(∇U∘∇U∘∇Uᵀ)
# (137)	tr(∇U∘∇Uᵀ)tr(S∘S∘S∘S)
# (138)	tr(∇U∘∇Uᵀ)tr(S∘S∘S∘∇U)
# (139)	tr(∇U∘∇Uᵀ)tr(S∘S∘∇U∘∇U)
# (140)	tr(∇U∘∇Uᵀ)tr(S∘S∘∇U∘∇Uᵀ)
# (141)	tr(∇U∘∇Uᵀ)tr(S∘S∘∇Uᵀ∘∇U)
# (142)	tr(∇U∘∇Uᵀ)tr(S∘∇U∘S∘∇U)
# (143)	tr(∇U∘∇Uᵀ)tr(S∘∇U∘S∘∇Uᵀ)
# (144)	tr(∇U∘∇Uᵀ)tr(S∘∇U∘∇U∘∇U)
# (145)	tr(∇U∘∇Uᵀ)tr(S∘∇U∘∇U∘∇Uᵀ)
# (146)	tr(∇U∘∇Uᵀ)tr(S∘∇U∘∇Uᵀ∘∇U)
# (147)	tr(∇U∘∇Uᵀ)tr(S∘∇Uᵀ∘∇U∘∇U)
# (148)	tr(∇U∘∇Uᵀ)tr(∇U∘∇U∘∇U∘∇U)
# (149)	tr(∇U∘∇Uᵀ)tr(∇U∘∇U∘∇U∘∇Uᵀ)
# (150)	tr(∇U∘∇Uᵀ)tr(∇U∘∇U∘∇Uᵀ∘∇Uᵀ)
# (151)	tr(∇U∘∇Uᵀ)tr(∇U∘∇Uᵀ∘∇U∘∇Uᵀ)
# (152)	(tr(S∘S∘S))²
# (153)	tr(S∘S∘S)tr(S∘S∘∇U)
# (154)	tr(S∘S∘S)tr(S∘∇U∘∇U)
# (155)	tr(S∘S∘S)tr(S∘∇U∘∇Uᵀ)
# (156)	tr(S∘S∘S)tr(S∘∇Uᵀ∘∇U)
# (157)	tr(S∘S∘S)tr(∇U∘∇U∘∇U)
# (158)	tr(S∘S∘S)tr(∇U∘∇U∘∇Uᵀ)
# (159)	tr(S∘S∘S)tr(S∘S∘S∘S)
# (160)	tr(S∘S∘S)tr(S∘S∘S∘∇U)
# (161)	tr(S∘S∘S)tr(S∘S∘∇U∘∇U)
# (162)	tr(S∘S∘S)tr(S∘S∘∇U∘∇Uᵀ)
# (163)	tr(S∘S∘S)tr(S∘S∘∇Uᵀ∘∇U)
# (164)	tr(S∘S∘S)tr(S∘∇U∘S∘∇U)
# (165)	tr(S∘S∘S)tr(S∘∇U∘S∘∇Uᵀ)
# (166)	tr(S∘S∘S)tr(S∘∇U∘∇U∘∇U)
# (167)	tr(S∘S∘S)tr(S∘∇U∘∇U∘∇Uᵀ)
# (168)	tr(S∘S∘S)tr(S∘∇U∘∇Uᵀ∘∇U)
# (169)	tr(S∘S∘S)tr(S∘∇Uᵀ∘∇U∘∇U)
# (170)	tr(S∘S∘S)tr(∇U∘∇U∘∇U∘∇U)
# (171)	tr(S∘S∘S)tr(∇U∘∇U∘∇U∘∇Uᵀ)
# (172)	tr(S∘S∘S)tr(∇U∘∇U∘∇Uᵀ∘∇Uᵀ)
# (173)	tr(S∘S∘S)tr(∇U∘∇Uᵀ∘∇U∘∇Uᵀ)
# (174)	(tr(S∘S∘∇U))²
# (175)	tr(S∘S∘∇U)tr(S∘∇U∘∇U)
# (176)	tr(S∘S∘∇U)tr(S∘∇U∘∇Uᵀ)
# (177)	tr(S∘S∘∇U)tr(S∘∇Uᵀ∘∇U)
# (178)	tr(S∘S∘∇U)tr(∇U∘∇U∘∇U)
# (179)	tr(S∘S∘∇U)tr(∇U∘∇U∘∇Uᵀ)
# (180)	tr(S∘S∘∇U)tr(S∘S∘S∘S)
# (181)	tr(S∘S∘∇U)tr(S∘S∘S∘∇U)
# (182)	tr(S∘S∘∇U)tr(S∘S∘∇U∘∇U)
# (183)	tr(S∘S∘∇U)tr(S∘S∘∇U∘∇Uᵀ)
# (184)	tr(S∘S∘∇U)tr(S∘S∘∇Uᵀ∘∇U)
# (185)	tr(S∘S∘∇U)tr(S∘∇U∘S∘∇U)
# (186)	tr(S∘S∘∇U)tr(S∘∇U∘S∘∇Uᵀ)
# (187)	tr(S∘S∘∇U)tr(S∘∇U∘∇U∘∇U)
# (188)	tr(S∘S∘∇U)tr(S∘∇U∘∇U∘∇Uᵀ)
# (189)	tr(S∘S∘∇U)tr(S∘∇U∘∇Uᵀ∘∇U)
# (190)	tr(S∘S∘∇U)tr(S∘∇Uᵀ∘∇U∘∇U)
# (191)	tr(S∘S∘∇U)tr(∇U∘∇U∘∇U∘∇U)
# (192)	tr(S∘S∘∇U)tr(∇U∘∇U∘∇U∘∇Uᵀ)
# (193)	tr(S∘S∘∇U)tr(∇U∘∇U∘∇Uᵀ∘∇Uᵀ)
# (194)	tr(S∘S∘∇U)tr(∇U∘∇Uᵀ∘∇U∘∇Uᵀ)
# (195)	(tr(S∘∇U∘∇U))²
# (196)	tr(S∘∇U∘∇U)tr(S∘∇U∘∇Uᵀ)
# (197)	tr(S∘∇U∘∇U)tr(S∘∇Uᵀ∘∇U)
# (198)	tr(S∘∇U∘∇U)tr(∇U∘∇U∘∇U)
# (199)	tr(S∘∇U∘∇U)tr(∇U∘∇U∘∇Uᵀ)
# (200)	tr(S∘∇U∘∇U)tr(S∘S∘S∘S)
# (201)	tr(S∘∇U∘∇U)tr(S∘S∘S∘∇U)
# (202)	tr(S∘∇U∘∇U)tr(S∘S∘∇U∘∇U)
# (203)	tr(S∘∇U∘∇U)tr(S∘S∘∇U∘∇Uᵀ)
# (204)	tr(S∘∇U∘∇U)tr(S∘S∘∇Uᵀ∘∇U)
# (205)	tr(S∘∇U∘∇U)tr(S∘∇U∘S∘∇U)
# (206)	tr(S∘∇U∘∇U)tr(S∘∇U∘S∘∇Uᵀ)
# (207)	tr(S∘∇U∘∇U)tr(S∘∇U∘∇U∘∇U)
# (208)	tr(S∘∇U∘∇U)tr(S∘∇U∘∇U∘∇Uᵀ)
# (209)	tr(S∘∇U∘∇U)tr(S∘∇U∘∇Uᵀ∘∇U)
# (210)	tr(S∘∇U∘∇U)tr(S∘∇Uᵀ∘∇U∘∇U)
# (211)	tr(S∘∇U∘∇U)tr(∇U∘∇U∘∇U∘∇U)
# (212)	tr(S∘∇U∘∇U)tr(∇U∘∇U∘∇U∘∇Uᵀ)
# (213)	tr(S∘∇U∘∇U)tr(∇U∘∇U∘∇Uᵀ∘∇Uᵀ)
# (214)	tr(S∘∇U∘∇U)tr(∇U∘∇Uᵀ∘∇U∘∇Uᵀ)
# (215)	(tr(S∘∇U∘∇Uᵀ))²
# (216)	tr(S∘∇U∘∇Uᵀ)tr(S∘∇Uᵀ∘∇U)
# (217)	tr(S∘∇U∘∇Uᵀ)tr(∇U∘∇U∘∇U)
# (218)	tr(S∘∇U∘∇Uᵀ)tr(∇U∘∇U∘∇Uᵀ)
# (219)	tr(S∘∇U∘∇Uᵀ)tr(S∘S∘S∘S)
# (220)	tr(S∘∇U∘∇Uᵀ)tr(S∘S∘S∘∇U)
# (221)	tr(S∘∇U∘∇Uᵀ)tr(S∘S∘∇U∘∇U)
# (222)	tr(S∘∇U∘∇Uᵀ)tr(S∘S∘∇U∘∇Uᵀ)
# (223)	tr(S∘∇U∘∇Uᵀ)tr(S∘S∘∇Uᵀ∘∇U)
# (224)	tr(S∘∇U∘∇Uᵀ)tr(S∘∇U∘S∘∇U)
# (225)	tr(S∘∇U∘∇Uᵀ)tr(S∘∇U∘S∘∇Uᵀ)
# (226)	tr(S∘∇U∘∇Uᵀ)tr(S∘∇U∘∇U∘∇U)
# (227)	tr(S∘∇U∘∇Uᵀ)tr(S∘∇U∘∇U∘∇Uᵀ)
# (228)	tr(S∘∇U∘∇Uᵀ)tr(S∘∇U∘∇Uᵀ∘∇U)
# (229)	tr(S∘∇U∘∇Uᵀ)tr(S∘∇Uᵀ∘∇U∘∇U)
# (230)	tr(S∘∇U∘∇Uᵀ)tr(∇U∘∇U∘∇U∘∇U)
# (231)	tr(S∘∇U∘∇Uᵀ)tr(∇U∘∇U∘∇U∘∇Uᵀ)
# (232)	tr(S∘∇U∘∇Uᵀ)tr(∇U∘∇U∘∇Uᵀ∘∇Uᵀ)
# (233)	tr(S∘∇U∘∇Uᵀ)tr(∇U∘∇Uᵀ∘∇U∘∇Uᵀ)
# (234)	(tr(S∘∇Uᵀ∘∇U))²
# (235)	tr(S∘∇Uᵀ∘∇U)tr(∇U∘∇U∘∇U)
# (236)	tr(S∘∇Uᵀ∘∇U)tr(∇U∘∇U∘∇Uᵀ)
# (237)	tr(S∘∇Uᵀ∘∇U)tr(S∘S∘S∘S)
# (238)	tr(S∘∇Uᵀ∘∇U)tr(S∘S∘S∘∇U)
# (239)	tr(S∘∇Uᵀ∘∇U)tr(S∘S∘∇U∘∇U)
# (240)	tr(S∘∇Uᵀ∘∇U)tr(S∘S∘∇U∘∇Uᵀ)
# (241)	tr(S∘∇Uᵀ∘∇U)tr(S∘S∘∇Uᵀ∘∇U)
# (242)	tr(S∘∇Uᵀ∘∇U)tr(S∘∇U∘S∘∇U)
# (243)	tr(S∘∇Uᵀ∘∇U)tr(S∘∇U∘S∘∇Uᵀ)
# (244)	tr(S∘∇Uᵀ∘∇U)tr(S∘∇U∘∇U∘∇U)
# (245)	tr(S∘∇Uᵀ∘∇U)tr(S∘∇U∘∇U∘∇Uᵀ)
# (246)	tr(S∘∇Uᵀ∘∇U)tr(S∘∇U∘∇Uᵀ∘∇U)
# (247)	tr(S∘∇Uᵀ∘∇U)tr(S∘∇Uᵀ∘∇U∘∇U)
# (248)	tr(S∘∇Uᵀ∘∇U)tr(∇U∘∇U∘∇U∘∇U)
# (249)	tr(S∘∇Uᵀ∘∇U)tr(∇U∘∇U∘∇U∘∇Uᵀ)
# (250)	tr(S∘∇Uᵀ∘∇U)tr(∇U∘∇U∘∇Uᵀ∘∇Uᵀ)
# (251)	tr(S∘∇Uᵀ∘∇U)tr(∇U∘∇Uᵀ∘∇U∘∇Uᵀ)
# (252)	(tr(∇U∘∇U∘∇U))²
# (253)	tr(∇U∘∇U∘∇U)tr(∇U∘∇U∘∇Uᵀ)
# (254)	tr(∇U∘∇U∘∇U)tr(S∘S∘S∘S)
# (255)	tr(∇U∘∇U∘∇U)tr(S∘S∘S∘∇U)
# (256)	tr(∇U∘∇U∘∇U)tr(S∘S∘∇U∘∇U)
# (257)	tr(∇U∘∇U∘∇U)tr(S∘S∘∇U∘∇Uᵀ)
# (258)	tr(∇U∘∇U∘∇U)tr(S∘S∘∇Uᵀ∘∇U)
# (259)	tr(∇U∘∇U∘∇U)tr(S∘∇U∘S∘∇U)
# (260)	tr(∇U∘∇U∘∇U)tr(S∘∇U∘S∘∇Uᵀ)
# (261)	tr(∇U∘∇U∘∇U)tr(S∘∇U∘∇U∘∇U)
# (262)	tr(∇U∘∇U∘∇U)tr(S∘∇U∘∇U∘∇Uᵀ)
# (263)	tr(∇U∘∇U∘∇U)tr(S∘∇U∘∇Uᵀ∘∇U)
# (264)	tr(∇U∘∇U∘∇U)tr(S∘∇Uᵀ∘∇U∘∇U)
# (265)	tr(∇U∘∇U∘∇U)tr(∇U∘∇U∘∇U∘∇U)
# (266)	tr(∇U∘∇U∘∇U)tr(∇U∘∇U∘∇U∘∇Uᵀ)
# (267)	tr(∇U∘∇U∘∇U)tr(∇U∘∇U∘∇Uᵀ∘∇Uᵀ)
# (268)	tr(∇U∘∇U∘∇U)tr(∇U∘∇Uᵀ∘∇U∘∇Uᵀ)
# (269)	(tr(∇U∘∇U∘∇Uᵀ))²
# (270)	tr(∇U∘∇U∘∇Uᵀ)tr(S∘S∘S∘S)
# (271)	tr(∇U∘∇U∘∇Uᵀ)tr(S∘S∘S∘∇U)
# (272)	tr(∇U∘∇U∘∇Uᵀ)tr(S∘S∘∇U∘∇U)
# (273)	tr(∇U∘∇U∘∇Uᵀ)tr(S∘S∘∇U∘∇Uᵀ)
# (274)	tr(∇U∘∇U∘∇Uᵀ)tr(S∘S∘∇Uᵀ∘∇U)
# (275)	tr(∇U∘∇U∘∇Uᵀ)tr(S∘∇U∘S∘∇U)
# (276)	tr(∇U∘∇U∘∇Uᵀ)tr(S∘∇U∘S∘∇Uᵀ)
# (277)	tr(∇U∘∇U∘∇Uᵀ)tr(S∘∇U∘∇U∘∇U)
# (278)	tr(∇U∘∇U∘∇Uᵀ)tr(S∘∇U∘∇U∘∇Uᵀ)
# (279)	tr(∇U∘∇U∘∇Uᵀ)tr(S∘∇U∘∇Uᵀ∘∇U)
# (280)	tr(∇U∘∇U∘∇Uᵀ)tr(S∘∇Uᵀ∘∇U∘∇U)
# (281)	tr(∇U∘∇U∘∇Uᵀ)tr(∇U∘∇U∘∇U∘∇U)
# (282)	tr(∇U∘∇U∘∇Uᵀ)tr(∇U∘∇U∘∇U∘∇Uᵀ)
# (283)	tr(∇U∘∇U∘∇Uᵀ)tr(∇U∘∇U∘∇Uᵀ∘∇Uᵀ)
# (284)	tr(∇U∘∇U∘∇Uᵀ)tr(∇U∘∇Uᵀ∘∇U∘∇Uᵀ)
# (285)	(tr(S∘S∘S∘S))²
# (286)	tr(S∘S∘S∘S)tr(S∘S∘S∘∇U)
# (287)	tr(S∘S∘S∘S)tr(S∘S∘∇U∘∇U)
# (288)	tr(S∘S∘S∘S)tr(S∘S∘∇U∘∇Uᵀ)
# (289)	tr(S∘S∘S∘S)tr(S∘S∘∇Uᵀ∘∇U)
# (290)	tr(S∘S∘S∘S)tr(S∘∇U∘S∘∇U)
# (291)	tr(S∘S∘S∘S)tr(S∘∇U∘S∘∇Uᵀ)
# (292)	tr(S∘S∘S∘S)tr(S∘∇U∘∇U∘∇U)
# (293)	tr(S∘S∘S∘S)tr(S∘∇U∘∇U∘∇Uᵀ)
# (294)	tr(S∘S∘S∘S)tr(S∘∇U∘∇Uᵀ∘∇U)
# (295)	tr(S∘S∘S∘S)tr(S∘∇Uᵀ∘∇U∘∇U)
# (296)	tr(S∘S∘S∘S)tr(∇U∘∇U∘∇U∘∇U)
# (297)	tr(S∘S∘S∘S)tr(∇U∘∇U∘∇U∘∇Uᵀ)
# (298)	tr(S∘S∘S∘S)tr(∇U∘∇U∘∇Uᵀ∘∇Uᵀ)
# (299)	tr(S∘S∘S∘S)tr(∇U∘∇Uᵀ∘∇U∘∇Uᵀ)
# (300)	(tr(S∘S∘S∘∇U))²
# (301)	tr(S∘S∘S∘∇U)tr(S∘S∘∇U∘∇U)
# (302)	tr(S∘S∘S∘∇U)tr(S∘S∘∇U∘∇Uᵀ)
# (303)	tr(S∘S∘S∘∇U)tr(S∘S∘∇Uᵀ∘∇U)
# (304)	tr(S∘S∘S∘∇U)tr(S∘∇U∘S∘∇U)
# (305)	tr(S∘S∘S∘∇U)tr(S∘∇U∘S∘∇Uᵀ)
# (306)	tr(S∘S∘S∘∇U)tr(S∘∇U∘∇U∘∇U)
# (307)	tr(S∘S∘S∘∇U)tr(S∘∇U∘∇U∘∇Uᵀ)
# (308)	tr(S∘S∘S∘∇U)tr(S∘∇U∘∇Uᵀ∘∇U)
# (309)	tr(S∘S∘S∘∇U)tr(S∘∇Uᵀ∘∇U∘∇U)
# (310)	tr(S∘S∘S∘∇U)tr(∇U∘∇U∘∇U∘∇U)
# (311)	tr(S∘S∘S∘∇U)tr(∇U∘∇U∘∇U∘∇Uᵀ)
# (312)	tr(S∘S∘S∘∇U)tr(∇U∘∇U∘∇Uᵀ∘∇Uᵀ)
# (313)	tr(S∘S∘S∘∇U)tr(∇U∘∇Uᵀ∘∇U∘∇Uᵀ)
# (314)	(tr(S∘S∘∇U∘∇U))²
# (315)	tr(S∘S∘∇U∘∇U)tr(S∘S∘∇U∘∇Uᵀ)
# (316)	tr(S∘S∘∇U∘∇U)tr(S∘S∘∇Uᵀ∘∇U)
# (317)	tr(S∘S∘∇U∘∇U)tr(S∘∇U∘S∘∇U)
# (318)	tr(S∘S∘∇U∘∇U)tr(S∘∇U∘S∘∇Uᵀ)
# (319)	tr(S∘S∘∇U∘∇U)tr(S∘∇U∘∇U∘∇U)
# (320)	tr(S∘S∘∇U∘∇U)tr(S∘∇U∘∇U∘∇Uᵀ)
# (321)	tr(S∘S∘∇U∘∇U)tr(S∘∇U∘∇Uᵀ∘∇U)
# (322)	tr(S∘S∘∇U∘∇U)tr(S∘∇Uᵀ∘∇U∘∇U)
# (323)	tr(S∘S∘∇U∘∇U)tr(∇U∘∇U∘∇U∘∇U)
# (324)	tr(S∘S∘∇U∘∇U)tr(∇U∘∇U∘∇U∘∇Uᵀ)
# (325)	tr(S∘S∘∇U∘∇U)tr(∇U∘∇U∘∇Uᵀ∘∇Uᵀ)
# (326)	tr(S∘S∘∇U∘∇U)tr(∇U∘∇Uᵀ∘∇U∘∇Uᵀ)
# (327)	(tr(S∘S∘∇U∘∇Uᵀ))²
# (328)	tr(S∘S∘∇U∘∇Uᵀ)tr(S∘S∘∇Uᵀ∘∇U)
# (329)	tr(S∘S∘∇U∘∇Uᵀ)tr(S∘∇U∘S∘∇U)
# (330)	tr(S∘S∘∇U∘∇Uᵀ)tr(S∘∇U∘S∘∇Uᵀ)
# (331)	tr(S∘S∘∇U∘∇Uᵀ)tr(S∘∇U∘∇U∘∇U)
# (332)	tr(S∘S∘∇U∘∇Uᵀ)tr(S∘∇U∘∇U∘∇Uᵀ)
# (333)	tr(S∘S∘∇U∘∇Uᵀ)tr(S∘∇U∘∇Uᵀ∘∇U)
# (334)	tr(S∘S∘∇U∘∇Uᵀ)tr(S∘∇Uᵀ∘∇U∘∇U)
# (335)	tr(S∘S∘∇U∘∇Uᵀ)tr(∇U∘∇U∘∇U∘∇U)
# (336)	tr(S∘S∘∇U∘∇Uᵀ)tr(∇U∘∇U∘∇U∘∇Uᵀ)
# (337)	tr(S∘S∘∇U∘∇Uᵀ)tr(∇U∘∇U∘∇Uᵀ∘∇Uᵀ)
# (338)	tr(S∘S∘∇U∘∇Uᵀ)tr(∇U∘∇Uᵀ∘∇U∘∇Uᵀ)
# (339)	(tr(S∘S∘∇Uᵀ∘∇U))²
# (340)	tr(S∘S∘∇Uᵀ∘∇U)tr(S∘∇U∘S∘∇U)
# (341)	tr(S∘S∘∇Uᵀ∘∇U)tr(S∘∇U∘S∘∇Uᵀ)
# (342)	tr(S∘S∘∇Uᵀ∘∇U)tr(S∘∇U∘∇U∘∇U)
# (343)	tr(S∘S∘∇Uᵀ∘∇U)tr(S∘∇U∘∇U∘∇Uᵀ)
# (344)	tr(S∘S∘∇Uᵀ∘∇U)tr(S∘∇U∘∇Uᵀ∘∇U)
# (345)	tr(S∘S∘∇Uᵀ∘∇U)tr(S∘∇Uᵀ∘∇U∘∇U)
# (346)	tr(S∘S∘∇Uᵀ∘∇U)tr(∇U∘∇U∘∇U∘∇U)
# (347)	tr(S∘S∘∇Uᵀ∘∇U)tr(∇U∘∇U∘∇U∘∇Uᵀ)
# (348)	tr(S∘S∘∇Uᵀ∘∇U)tr(∇U∘∇U∘∇Uᵀ∘∇Uᵀ)
# (349)	tr(S∘S∘∇Uᵀ∘∇U)tr(∇U∘∇Uᵀ∘∇U∘∇Uᵀ)
# (350)	(tr(S∘∇U∘S∘∇U))²
# (351)	tr(S∘∇U∘S∘∇U)tr(S∘∇U∘S∘∇Uᵀ)
# (352)	tr(S∘∇U∘S∘∇U)tr(S∘∇U∘∇U∘∇U)
# (353)	tr(S∘∇U∘S∘∇U)tr(S∘∇U∘∇U∘∇Uᵀ)
# (354)	tr(S∘∇U∘S∘∇U)tr(S∘∇U∘∇Uᵀ∘∇U)
# (355)	tr(S∘∇U∘S∘∇U)tr(S∘∇Uᵀ∘∇U∘∇U)
# (356)	tr(S∘∇U∘S∘∇U)tr(∇U∘∇U∘∇U∘∇U)
# (357)	tr(S∘∇U∘S∘∇U)tr(∇U∘∇U∘∇U∘∇Uᵀ)
# (358)	tr(S∘∇U∘S∘∇U)tr(∇U∘∇U∘∇Uᵀ∘∇Uᵀ)
# (359)	tr(S∘∇U∘S∘∇U)tr(∇U∘∇Uᵀ∘∇U∘∇Uᵀ)
# (360)	(tr(S∘∇U∘S∘∇Uᵀ))²
# (361)	tr(S∘∇U∘S∘∇Uᵀ)tr(S∘∇U∘∇U∘∇U)
# (362)	tr(S∘∇U∘S∘∇Uᵀ)tr(S∘∇U∘∇U∘∇Uᵀ)
# (363)	tr(S∘∇U∘S∘∇Uᵀ)tr(S∘∇U∘∇Uᵀ∘∇U)
# (364)	tr(S∘∇U∘S∘∇Uᵀ)tr(S∘∇Uᵀ∘∇U∘∇U)
# (365)	tr(S∘∇U∘S∘∇Uᵀ)tr(∇U∘∇U∘∇U∘∇U)
# (366)	tr(S∘∇U∘S∘∇Uᵀ)tr(∇U∘∇U∘∇U∘∇Uᵀ)
# (367)	tr(S∘∇U∘S∘∇Uᵀ)tr(∇U∘∇U∘∇Uᵀ∘∇Uᵀ)
# (368)	tr(S∘∇U∘S∘∇Uᵀ)tr(∇U∘∇Uᵀ∘∇U∘∇Uᵀ)
# (369)	(tr(S∘∇U∘∇U∘∇U))²
# (370)	tr(S∘∇U∘∇U∘∇U)tr(S∘∇U∘∇U∘∇Uᵀ)
# (371)	tr(S∘∇U∘∇U∘∇U)tr(S∘∇U∘∇Uᵀ∘∇U)
# (372)	tr(S∘∇U∘∇U∘∇U)tr(S∘∇Uᵀ∘∇U∘∇U)
# (373)	tr(S∘∇U∘∇U∘∇U)tr(∇U∘∇U∘∇U∘∇U)
# (374)	tr(S∘∇U∘∇U∘∇U)tr(∇U∘∇U∘∇U∘∇Uᵀ)
# (375)	tr(S∘∇U∘∇U∘∇U)tr(∇U∘∇U∘∇Uᵀ∘∇Uᵀ)
# (376)	tr(S∘∇U∘∇U∘∇U)tr(∇U∘∇Uᵀ∘∇U∘∇Uᵀ)
# (377)	(tr(S∘∇U∘∇U∘∇Uᵀ))²
# (378)	tr(S∘∇U∘∇U∘∇Uᵀ)tr(S∘∇U∘∇Uᵀ∘∇U)
# (379)	tr(S∘∇U∘∇U∘∇Uᵀ)tr(S∘∇Uᵀ∘∇U∘∇U)
# (380)	tr(S∘∇U∘∇U∘∇Uᵀ)tr(∇U∘∇U∘∇U∘∇U)
# (381)	tr(S∘∇U∘∇U∘∇Uᵀ)tr(∇U∘∇U∘∇U∘∇Uᵀ)
# (382)	tr(S∘∇U∘∇U∘∇Uᵀ)tr(∇U∘∇U∘∇Uᵀ∘∇Uᵀ)
# (383)	tr(S∘∇U∘∇U∘∇Uᵀ)tr(∇U∘∇Uᵀ∘∇U∘∇Uᵀ)
# (384)	(tr(S∘∇U∘∇Uᵀ∘∇U))²
# (385)	tr(S∘∇U∘∇Uᵀ∘∇U)tr(S∘∇Uᵀ∘∇U∘∇U)
# (386)	tr(S∘∇U∘∇Uᵀ∘∇U)tr(∇U∘∇U∘∇U∘∇U)
# (387)	tr(S∘∇U∘∇Uᵀ∘∇U)tr(∇U∘∇U∘∇U∘∇Uᵀ)
# (388)	tr(S∘∇U∘∇Uᵀ∘∇U)tr(∇U∘∇U∘∇Uᵀ∘∇Uᵀ)
# (389)	tr(S∘∇U∘∇Uᵀ∘∇U)tr(∇U∘∇Uᵀ∘∇U∘∇Uᵀ)
# (390)	(tr(S∘∇Uᵀ∘∇U∘∇U))²
# (391)	tr(S∘∇Uᵀ∘∇U∘∇U)tr(∇U∘∇U∘∇U∘∇U)
# (392)	tr(S∘∇Uᵀ∘∇U∘∇U)tr(∇U∘∇U∘∇U∘∇Uᵀ)
# (393)	tr(S∘∇Uᵀ∘∇U∘∇U)tr(∇U∘∇U∘∇Uᵀ∘∇Uᵀ)
# (394)	tr(S∘∇Uᵀ∘∇U∘∇U)tr(∇U∘∇Uᵀ∘∇U∘∇Uᵀ)
# (395)	(tr(∇U∘∇U∘∇U∘∇U))²
# (396)	tr(∇U∘∇U∘∇U∘∇U)tr(∇U∘∇U∘∇U∘∇Uᵀ)
# (397)	tr(∇U∘∇U∘∇U∘∇U)tr(∇U∘∇U∘∇Uᵀ∘∇Uᵀ)
# (398)	tr(∇U∘∇U∘∇U∘∇U)tr(∇U∘∇Uᵀ∘∇U∘∇Uᵀ)
# (399)	(tr(∇U∘∇U∘∇U∘∇Uᵀ))²
# (400)	tr(∇U∘∇U∘∇U∘∇Uᵀ)tr(∇U∘∇U∘∇Uᵀ∘∇Uᵀ)
# (401)	tr(∇U∘∇U∘∇U∘∇Uᵀ)tr(∇U∘∇Uᵀ∘∇U∘∇Uᵀ)
# (402)	(tr(∇U∘∇U∘∇Uᵀ∘∇Uᵀ))²
# (403)	tr(∇U∘∇U∘∇Uᵀ∘∇Uᵀ)tr(∇U∘∇Uᵀ∘∇U∘∇Uᵀ)
# (404)	(tr(∇U∘∇Uᵀ∘∇U∘∇Uᵀ))²

# %% [markdown]
# Now it is time to combine our matrix library and scalar library.

# %%
library = library + library_trace*library
len(library)
# Out:
# 28014

# %% [markdown]
# We end up with a gigantic library we certainly want to trim, so we do by specifying the maximum degree in each variable:

# %%
library.trim({'S':2, '∇U':1})
# Out:
# Type of feature output: matrix
# Symmetry of features: symmetric
# Variables names: {'S', '∇U', '∇Uᵀ'}
# Variables transpose map: {'S': 'S', '∇U': '∇Uᵀ', '∇Uᵀ': '∇U'}
# Number of feature_functions: 22
# (0)	I
# (1)	S
# (2)	∇U + (∇U)ᵀ
# (3)	S∘S
# (4)	S∘∇U + (S∘∇U)ᵀ
# (5)	S∘∇Uᵀ + (S∘∇Uᵀ)ᵀ
# (6)	S∘S∘∇U + (S∘S∘∇U)ᵀ
# (7)	S∘S∘∇Uᵀ + (S∘S∘∇Uᵀ)ᵀ
# (8)	S∘∇U∘S + (S∘∇U∘S)ᵀ
# (9)	tr(S)I
# (10)	tr(S)S
# (11)	tr(S)(∇U + (∇U)ᵀ)
# (12)	tr(S)(S∘∇U + (S∘∇U)ᵀ)
# (13)	tr(S)(S∘∇Uᵀ + (S∘∇Uᵀ)ᵀ)
# (14)	tr(S∘S)I
# (15)	tr(S∘S)(∇U + (∇U)ᵀ)
# (16)	tr(S∘∇U)I
# (17)	tr(S∘∇U)S
# (18)	tr(S∘S∘∇U)I
# (19)	(tr(S))²I
# (20)	(tr(S))²(∇U + (∇U)ᵀ)
# (21)	tr(S)tr(S∘∇U)I

# %% [markdown]
# ## Example with Strain/Vorticity
# In the following example, we will use the strain rate/ vorticity split of the velocity gradient:
# $$
# \nabla U = D + W
# $$
# where $D$ is symmetric and $W$ is skew-symmetric.

# %%
variable_names = {'S', 'D', 'W'}
transpose_map = {'S':'S', 'D':'D', 'W':'-W'}  # Note the '-W' to label skew-symmetry
library = FeatureLibrary.from_polynomial_matrices(variable_names=variable_names, 
                                                  transpose_map=transpose_map, 
                                                  n_terms=4, intercept=True, symmetry='symmetric')
library.trim({'S':2, 'D':2, 'W':1})
# Out:
# Type of feature output: matrix
# Symmetry of features: symmetric
# Variables names: {'S', 'W', 'D'}
# Variables transpose map: {'S': 'S', 'D': 'D', 'W': '-W'}
# Number of feature_functions: 34
# (0)	I
# (1)	D
# (2)	S
# (3)	D∘D
# (4)	D∘S + (D∘S)ᵀ
# (5)	D∘W + (D∘W)ᵀ
# (6)	S∘S
# (7)	S∘W + (S∘W)ᵀ
# (8)	D∘D∘S + (D∘D∘S)ᵀ
# (9)	D∘D∘W + (D∘D∘W)ᵀ
# (10)	D∘S∘D
# (11)	D∘S∘S + (D∘S∘S)ᵀ
# (12)	D∘S∘W + (D∘S∘W)ᵀ
# (13)	S∘D∘S
# (14)	S∘D∘W + (S∘D∘W)ᵀ
# (15)	S∘S∘W + (S∘S∘W)ᵀ
# (16)	S∘W∘D + (S∘W∘D)ᵀ
# (17)	S∘W∘S + (S∘W∘S)ᵀ
# (18)	D∘D∘S∘S + (D∘D∘S∘S)ᵀ
# (19)	D∘D∘S∘W + (D∘D∘S∘W)ᵀ
# (20)	D∘D∘W∘S + (D∘D∘W∘S)ᵀ
# (21)	D∘S∘D∘S + (D∘S∘D∘S)ᵀ
# (22)	D∘S∘D∘W + (D∘S∘D∘W)ᵀ
# (23)	D∘S∘S∘D
# (24)	D∘S∘S∘W + (D∘S∘S∘W)ᵀ
# (25)	D∘S∘W∘D + (D∘S∘W∘D)ᵀ
# (26)	D∘S∘W∘S + (D∘S∘W∘S)ᵀ
# (27)	D∘W∘D∘S + (D∘W∘D∘S)ᵀ
# (28)	D∘W∘S∘S + (D∘W∘S∘S)ᵀ
# (29)	S∘D∘D∘S
# (30)	S∘D∘D∘W + (S∘D∘D∘W)ᵀ
# (31)	S∘D∘S∘W + (S∘D∘S∘W)ᵀ
# (32)	S∘D∘W∘S + (S∘D∘W∘S)ᵀ
# (33)	S∘S∘D∘W + (S∘S∘D∘W)ᵀ

# %%
library_trace = FeatureLibrary.from_polynomial_traces(variable_names, transpose_map, n_terms=4, intercept=False)
library_trace.remove_by_name('tr(D)')
# Out:
# Type of feature output: scalar
# Variables names: {'S', 'W', 'D'}
# Variables transpose map: {'S': 'S', 'D': 'D', 'W': '-W'}
# Number of feature_functions: 37
# (0)	tr(S)
# (1)	tr(D∘D)
# (2)	tr(D∘S)
# (3)	tr(D∘W)
# (4)	tr(S∘S)
# (5)	tr(S∘W)
# (6)	tr(W∘W)
# (7)	tr(D∘D∘D)
# (8)	tr(D∘D∘S)
# (9)	tr(D∘D∘W)
# (10)	tr(D∘S∘S)
# (11)	tr(D∘S∘W)
# (12)	tr(D∘W∘W)
# (13)	tr(S∘S∘S)
# (14)	tr(S∘S∘W)
# (15)	tr(S∘W∘W)
# (16)	tr(D∘D∘D∘D)
# (17)	tr(D∘D∘D∘S)
# (18)	tr(D∘D∘D∘W)
# (19)	tr(D∘D∘S∘S)
# (20)	tr(D∘D∘S∘W)
# (21)	tr(D∘D∘W∘W)
# (22)	tr(D∘S∘D∘S)
# (23)	tr(D∘S∘D∘W)
# (24)	tr(D∘S∘S∘S)
# (25)	tr(D∘S∘S∘W)
# (26)	tr(D∘S∘W∘S)
# (27)	tr(D∘S∘W∘W)
# (28)	tr(D∘W∘D∘W)
# (29)	tr(D∘W∘S∘W)
# (30)	tr(D∘W∘W∘W)
# (31)	tr(S∘S∘S∘S)
# (32)	tr(S∘S∘S∘W)
# (33)	tr(S∘S∘W∘W)
# (34)	tr(S∘W∘S∘W)
# (35)	tr(S∘W∘W∘W)
# (36)	tr(W∘W∘W∘W)

# %%
library_trace = library_trace + library_trace*library_trace
library_trace.trim({'S':2, 'D':2, 'W':1})
library = library + library_trace*library
library.trim({'S':2, 'D':2, 'W':1})
# Out:
# Type of feature output: matrix
# Symmetry of features: symmetric
# Variables names: {'S', 'W', 'D'}
# Variables transpose map: {'S': 'S', 'D': 'D', 'W': '-W'}
# Number of feature_functions: 153
# (0)	I
# (1)	D
# (2)	S
# (3)	D∘D
# (4)	D∘S + (D∘S)ᵀ
# (5)	D∘W + (D∘W)ᵀ
# (6)	S∘S
# (7)	S∘W + (S∘W)ᵀ
# (8)	D∘D∘S + (D∘D∘S)ᵀ
# (9)	D∘D∘W + (D∘D∘W)ᵀ
# (10)	D∘S∘D
# (11)	D∘S∘S + (D∘S∘S)ᵀ
# (12)	D∘S∘W + (D∘S∘W)ᵀ
# (13)	S∘D∘S
# (14)	S∘D∘W + (S∘D∘W)ᵀ
# (15)	S∘S∘W + (S∘S∘W)ᵀ
# (16)	S∘W∘D + (S∘W∘D)ᵀ
# (17)	S∘W∘S + (S∘W∘S)ᵀ
# (18)	D∘D∘S∘S + (D∘D∘S∘S)ᵀ
# (19)	D∘D∘S∘W + (D∘D∘S∘W)ᵀ
# (20)	D∘D∘W∘S + (D∘D∘W∘S)ᵀ
# (21)	D∘S∘D∘S + (D∘S∘D∘S)ᵀ
# (22)	D∘S∘D∘W + (D∘S∘D∘W)ᵀ
# (23)	D∘S∘S∘D
# (24)	D∘S∘S∘W + (D∘S∘S∘W)ᵀ
# (25)	D∘S∘W∘D + (D∘S∘W∘D)ᵀ
# (26)	D∘S∘W∘S + (D∘S∘W∘S)ᵀ
# (27)	D∘W∘D∘S + (D∘W∘D∘S)ᵀ
# (28)	D∘W∘S∘S + (D∘W∘S∘S)ᵀ
# (29)	S∘D∘D∘S
# (30)	S∘D∘D∘W + (S∘D∘D∘W)ᵀ
# (31)	S∘D∘S∘W + (S∘D∘S∘W)ᵀ
# (32)	S∘D∘W∘S + (S∘D∘W∘S)ᵀ
# (33)	S∘S∘D∘W + (S∘S∘D∘W)ᵀ
# (34)	tr(S)I
# (35)	tr(S)D
# (36)	tr(S)S
# (37)	tr(S)D∘D
# (38)	tr(S)(D∘S + (D∘S)ᵀ)
# (39)	tr(S)(D∘W + (D∘W)ᵀ)
# (40)	tr(S)(S∘W + (S∘W)ᵀ)
# (41)	tr(S)(D∘D∘S + (D∘D∘S)ᵀ)
# (42)	tr(S)(D∘D∘W + (D∘D∘W)ᵀ)
# (43)	tr(S)D∘S∘D
# (44)	tr(S)(D∘S∘W + (D∘S∘W)ᵀ)
# (45)	tr(S)(S∘D∘W + (S∘D∘W)ᵀ)
# (46)	tr(S)(S∘W∘D + (S∘W∘D)ᵀ)
# (47)	tr(S)(D∘D∘S∘W + (D∘D∘S∘W)ᵀ)
# (48)	tr(S)(D∘D∘W∘S + (D∘D∘W∘S)ᵀ)
# (49)	tr(S)(D∘S∘D∘W + (D∘S∘D∘W)ᵀ)
# (50)	tr(S)(D∘S∘W∘D + (D∘S∘W∘D)ᵀ)
# (51)	tr(S)(D∘W∘D∘S + (D∘W∘D∘S)ᵀ)
# (52)	tr(S)(S∘D∘D∘W + (S∘D∘D∘W)ᵀ)
# (53)	tr(D∘D)I
# (54)	tr(D∘D)S
# (55)	tr(D∘D)S∘S
# (56)	tr(D∘D)(S∘W + (S∘W)ᵀ)
# (57)	tr(D∘D)(S∘S∘W + (S∘S∘W)ᵀ)
# (58)	tr(D∘D)(S∘W∘S + (S∘W∘S)ᵀ)
# (59)	tr(D∘S)I
# (60)	tr(D∘S)D
# (61)	tr(D∘S)S
# (62)	tr(D∘S)(D∘S + (D∘S)ᵀ)
# (63)	tr(D∘S)(D∘W + (D∘W)ᵀ)
# (64)	tr(D∘S)(S∘W + (S∘W)ᵀ)
# (65)	tr(D∘S)(D∘S∘W + (D∘S∘W)ᵀ)
# (66)	tr(D∘S)(S∘D∘W + (S∘D∘W)ᵀ)
# (67)	tr(D∘S)(S∘W∘D + (S∘W∘D)ᵀ)
# (68)	tr(D∘W)I
# (69)	tr(D∘W)D
# (70)	tr(D∘W)S
# (71)	tr(D∘W)(D∘S + (D∘S)ᵀ)
# (72)	tr(D∘W)S∘S
# (73)	tr(D∘W)(D∘S∘S + (D∘S∘S)ᵀ)
# (74)	tr(D∘W)S∘D∘S
# (75)	tr(S∘S)I
# (76)	tr(S∘S)D
# (77)	tr(S∘S)D∘D
# (78)	tr(S∘S)(D∘W + (D∘W)ᵀ)
# (79)	tr(S∘S)(D∘D∘W + (D∘D∘W)ᵀ)
# (80)	tr(S∘W)I
# (81)	tr(S∘W)D
# (82)	tr(S∘W)S
# (83)	tr(S∘W)D∘D
# (84)	tr(S∘W)(D∘S + (D∘S)ᵀ)
# (85)	tr(S∘W)(D∘D∘S + (D∘D∘S)ᵀ)
# (86)	tr(S∘W)D∘S∘D
# (87)	tr(D∘D∘S)I
# (88)	tr(D∘D∘S)S
# (89)	tr(D∘D∘S)(S∘W + (S∘W)ᵀ)
# (90)	tr(D∘D∘W)I
# (91)	tr(D∘D∘W)S
# (92)	tr(D∘D∘W)S∘S
# (93)	tr(D∘S∘S)I
# (94)	tr(D∘S∘S)D
# (95)	tr(D∘S∘S)(D∘W + (D∘W)ᵀ)
# (96)	tr(D∘S∘W)I
# (97)	tr(D∘S∘W)D
# (98)	tr(D∘S∘W)S
# (99)	tr(D∘S∘W)(D∘S + (D∘S)ᵀ)
# (100)	tr(S∘S∘W)I
# (101)	tr(S∘S∘W)D
# (102)	tr(S∘S∘W)D∘D
# (103)	tr(D∘D∘S∘S)I
# (104)	tr(D∘D∘S∘W)I
# (105)	tr(D∘D∘S∘W)S
# (106)	tr(D∘S∘D∘S)I
# (107)	tr(D∘S∘D∘W)I
# (108)	tr(D∘S∘D∘W)S
# (109)	tr(D∘S∘S∘W)I
# (110)	tr(D∘S∘S∘W)D
# (111)	tr(D∘S∘W∘S)I
# (112)	tr(D∘S∘W∘S)D
# (113)	(tr(S))²I
# (114)	(tr(S))²D
# (115)	(tr(S))²D∘D
# (116)	(tr(S))²(D∘W + (D∘W)ᵀ)
# (117)	(tr(S))²(D∘D∘W + (D∘D∘W)ᵀ)
# (118)	tr(S)tr(D∘D)I
# (119)	tr(S)tr(D∘D)S
# (120)	tr(S)tr(D∘D)(S∘W + (S∘W)ᵀ)
# (121)	tr(S)tr(D∘S)I
# (122)	tr(S)tr(D∘S)D
# (123)	tr(S)tr(D∘S)(D∘W + (D∘W)ᵀ)
# (124)	tr(S)tr(D∘W)I
# (125)	tr(S)tr(D∘W)D
# (126)	tr(S)tr(D∘W)S
# (127)	tr(S)tr(D∘W)(D∘S + (D∘S)ᵀ)
# (128)	tr(S)tr(S∘W)I
# (129)	tr(S)tr(S∘W)D
# (130)	tr(S)tr(S∘W)D∘D
# (131)	tr(S)tr(D∘D∘S)I
# (132)	tr(S)tr(D∘D∘W)I
# (133)	tr(S)tr(D∘D∘W)S
# (134)	tr(S)tr(D∘S∘W)I
# (135)	tr(S)tr(D∘S∘W)D
# (136)	tr(S)tr(D∘D∘S∘W)I
# (137)	tr(S)tr(D∘S∘D∘W)I
# (138)	tr(D∘D)tr(S∘S)I
# (139)	tr(D∘D)tr(S∘W)I
# (140)	tr(D∘D)tr(S∘W)S
# (141)	tr(D∘D)tr(S∘S∘W)I
# (142)	(tr(D∘S))²I
# (143)	tr(D∘S)tr(D∘W)I
# (144)	tr(D∘S)tr(D∘W)S
# (145)	tr(D∘S)tr(S∘W)I
# (146)	tr(D∘S)tr(S∘W)D
# (147)	tr(D∘S)tr(D∘S∘W)I
# (148)	tr(D∘W)tr(S∘S)I
# (149)	tr(D∘W)tr(S∘S)D
# (150)	tr(D∘W)tr(D∘S∘S)I
# (151)	tr(S∘S)tr(D∘D∘W)I
# (152)	tr(S∘W)tr(D∘D∘S)I

# %% [markdown]
# We can always add special terms inspired by common models. For example

# %%
FENEP_library_trace = FeatureLibrary.from_polynomial_traces({'A'}, {'A':'A'}, n_terms=1, intercept=False)
l2 = 10.
FENEP_library_trace.compose(lambda x: 1/(l2-x), f"({l2}-*)⁻¹")

FENEP_library = FeatureLibrary.from_polynomial_matrices(variable_names={'A', '∇U'}, transpose_map={'A':'A', '∇U':None}, n_terms=2, intercept=True, symmetry='symmetric')
FENEP_library.trim({'A':1, '∇U':1})

#FENEP_library.trim({'A':1, '∇U':1})
FENEP_library = FENEP_library + FENEP_library_trace*FENEP_library
FENEP_library
# Out:
# Type of feature output: matrix
# Symmetry of features: symmetric
# Variables names: {'A', '∇U'}
# Variables transpose map: {'A': 'A', '∇U': None}
# Number of feature_functions: 10
# (0)	I
# (1)	A
# (2)	∇U + (∇U)ᵀ
# (3)	A∘∇U + (A∘∇U)ᵀ
# (4)	∇U∘A + (∇U∘A)ᵀ
# (5)	(10.0-tr(A))⁻¹I
# (6)	(10.0-tr(A))⁻¹A
# (7)	(10.0-tr(A))⁻¹(∇U + (∇U)ᵀ)
# (8)	(10.0-tr(A))⁻¹(A∘∇U + (A∘∇U)ᵀ)
# (9)	(10.0-tr(A))⁻¹(∇U∘A + (∇U∘A)ᵀ)
